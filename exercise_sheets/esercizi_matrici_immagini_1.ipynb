# %% [markdown]
# # Esercizi Python Semplificati: Selezione e Navigazione nelle Immagini (RGB)
#
# In questo notebook lavoreremo sulle immagini intese come **matrici di pixel** (liste di liste).
# Ogni pixel è una **tupla di 3 numeri** `(R, G, B)` che rappresenta i colori Rosso, Verde e Blu (valori da 0 a 255).
#
# Tutti gli esercizi si concentrano sulla **selezione**, la **lettura** e la **navigazione** all'interno della matrice, senza effettuare modifiche o sostituzioni.
#
# ### Struttura degli indici:
# - `immagine[indice_riga]` -> Seleziona una riga intera.
# - `immagine[indice_riga][indice_colonna]` -> Seleziona un singolo pixel.
# - `immagine[indice_riga][indice_colonna][0]` -> Seleziona solo il canale Rosso (R) di quel pixel.
#
# Esegui subito la cella di setup qui sotto per iniziare!

# %%
# CELLA DI SETUP: Esegui questa cella per caricare l'immagine di test (4x4 pixel)
immagine_test = [
    [(255, 0, 0), (0, 255, 0), (0, 0, 255), (255, 255, 255)],     # Riga 0: Rosso, Verde, Blu, Bianco
    [(0, 0, 0), (255, 255, 0), (0, 255, 255), (255, 0, 255)],     # Riga 1: Nero, Giallo, Ciano, Magenta
    [(100, 100, 100), (200, 200, 200), (255, 0, 0), (0, 0, 0)],   # Riga 2: Grigio Scuro, Grigio Chiaro, Rosso, Nero
    [(255, 255, 255), (0, 255, 0), (120, 120, 120), (0, 0, 255)]  # Riga 3: Bianco, Verde, Grigio Medio, Blu
]

print("Immagine di test caricata! Sei pronto a navigare tra i pixel.")

# %% [markdown]
# ### Esercizio 1: Il Primo Pixel
# Seleziona il pixel posizionato nell'**angolo in alto a sinistra** (riga 0, colonna 0) di `immagine_test` e stampalo a video.

# %%
# Scrivi qui il tuo codice per l'Esercizio 1

# %% [markdown]
# ### Esercizio 2: L'Ultimo Pixel
# Seleziona il pixel posizionato nell'**angolo in basso a destra** (riga 3, colonna 3) di `immagine_test` e stampalo a video.

# %%
# Scrivi qui il tuo codice per l'Esercizio 2

# %% [markdown]
# ### Esercizio 3: Estrazione Canale Singolo
# Prendi il pixel situato a **riga 0, colonna 1** (il pixel Verde). Estrai da questo pixel **solo** il valore del canale **Verde (G)** (il secondo elemento della tupla) e stampalo.

# %%
# Scrivi qui il tuo codice per l'Esercizio 3

# %% [markdown]
# ### Esercizio 4: Selezione di una Riga Intera
# Seleziona l'intera **terza riga** (indice 2) di `immagine_test`. Salvala in una variabile chiamata `riga_selezionata` e stampala.

# %%
# Scrivi qui il tuo codice per l'Esercizio 4

# %% [markdown]
# ### Esercizio 5: Navigazione mista
# Prendi l'ultimo pixel della **seconda riga** (indice riga 1, indice colonna 3) ed estrai il valore del suo canale **Blu (B)** (il terzo elemento della tupla). Stampa il valore ottenuto.

# %%
# Scrivi qui il tuo codice per l'Esercizio 5

# %% [markdown]
# ### Esercizio 6: Scorrere una Riga
# Scrivi un ciclo `for` semplice per scorrere ed **esaminare uno alla volta** i pixel presenti nella **prima riga** (indice 0) di `immagine_test`. Stampa ogni pixel su una riga separata.

# %%
# Scrivi qui il tuo codice per l'Esercizio 6

# %% [markdown]
# ### Esercizio 7: Algoritmo Filtro - Contare i Pixel Bianchi
# Usa un **doppio ciclo `for` annidato** per scorrere tutti i pixel della matrice.
# Usa l'istruzione `if` per verificare se il pixel corrente è **completamente bianco** `(255, 255, 255)`. Conta quanti pixel bianchi ci sono in totale e stampa il risultato.

# %%
# Scrivi qui il tuo codice per l'Esercizio 7

# %% [markdown]
# ### Esercizio 8: Algoritmo Filtro - Trovare la Posizione dei Pixel Neri
# Scorri l'intera matrice `immagine_test` usando un doppio ciclo `for` combinato con `enumerate()` (per tracciare gli indici di riga e colonna).
# Se trovi un pixel **completamente nero** `(0, 0, 0)`, stampa a video le sue coordinate nel formato: `Riga: X, Colonna: Y`.

# %%
# Scrivi qui il tuo codice per l'Esercizio 8

# %% [markdown]
# ### Esercizio 9: Algoritmo Filtro - Selezione Mirata su Riga
# Scrivi un ciclo `for` per scorrere i pixel della **quarta riga** (indice 3). Usa un `if` per stampare **solo** i pixel che hanno il canale del **Rosso (R) uguale a 0**.

# %%
# Scrivi qui il tuo codice per l'Esercizio 9

# %% [markdown]
# ### Esercizio 10: Algoritmo Filtro - Controllo di Esistenza Rapido
# Scorri l'intera matrice per cercare se esiste almeno un pixel di colore **Verde** `(0, 255, 0)`.
# Usa un ciclo `for` annidato e un `if`. Non appena l'algoritmo trova il primo pixel verde, deve stampare `"Colore Verde individuato!"` e **fermarsi immediatamente** usando l'istruzione `break`.

# %%
# Scrivi qui il tuo codice per l'Esercizio 10
