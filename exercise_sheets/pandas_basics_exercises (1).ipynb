# %% [markdown]
# # Pandas Basics Exercises
# This notebook contains 10 exercises to practice the basics of pandas using the London Weather dataset (`london_weather.csv`).
#
# Topics covered:
# - Accessing columns (single and multiple)
# - `.loc[]` and `.iloc[]` positions/labels
# - Conditional row selection

# %% [markdown]
# ### Exercise 1: Load the Dataset
# Load the dataset `london_weather.csv` into a pandas DataFrame named `df`. Note that the file uses a semicolon (`;`) as a separator. Display the first 5 rows to verify it loaded correctly.

# %%
import pandas as pd

# Your code here

# %% [markdown]
# ### Exercise 2: Access a Single Column
# Select the `sunshine` column from the DataFrame and display its first 5 values.

# %%
# Your code here

# %% [markdown]
# ### Exercise 3: Access Multiple Columns
# Select the `date`, `max_temp`, and `min_temp` columns together and display the first 5 rows of this subset.

# %%
# Your code here

# %% [markdown]
# ### Exercise 4: Positional Indexing with `.iloc[]` (Rows and Columns)
# Use `.iloc[]` to select the first 5 rows and the first 4 columns of the DataFrame.

# %%
# Your code here

# %% [markdown]
# ### Exercise 5: Access a Specific Cell with `.iloc[]`
# Use `.iloc[]` to extract the specific value located at the 10th row (index 9) and the 5th column (index 4, which is `max_temp`).

# %%
# Your code here

# %% [markdown]
# ### Exercise 6: Label-based Indexing with `.loc[]`
# Use `.loc[]` to select rows with index labels from 10 to 15 (inclusive) and only the columns `date`, `mean_temp`, and `pressure`.

# %%
# Your code here

# %% [markdown]
# ### Exercise 7: Simple Conditional Row Selection
# Filter the DataFrame to find and display all rows where the `max_temp` is strictly greater than 35 degrees Celsius.

# %%
# Your code here

# %% [markdown]
# ### Exercise 8: Multiple Conditions Row Selection
# Filter the DataFrame to find all rows where `snow_depth` is greater than 10 (cm) AND `min_temp` is below 0 degrees Celsius.

# %%
# Your code here

# %% [markdown]
# ### Exercise 9: Conditional Selection with Specific Columns using `.loc[]`
# Use `.loc[]` to select only the `date` and `precipitation` columns for rows where `precipitation` is greater than 50 mm.

# %%
# Your code here

# %% [markdown]
# ### Exercise 10: Conditional Selection and Aggregation
# Find the average (mean) `global_radiation` for days where `cloud_cover` was less than or equal to 2.0.

# %%
# Your code here
