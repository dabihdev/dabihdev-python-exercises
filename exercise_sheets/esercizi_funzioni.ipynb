# %% [markdown]
# # Eserciziario su funzioni con algoritmi di ricerca o filtro
#
# Gli algoritmi di ricerca sono quelli che usano for e if insieme. Gli algoritmi filtro sono quelli che filtrano elementi da una lista o stringa iniziale in una lista o stringa inizialmente vuota, secondo certe condizioni. Anche qui si usano for e if insieme.

# %%
# 1. Scrivi una funzione che prende come argomento una lista di nomi (lista di stringhe)
# e una lettera (stringa), e restituisce una lista con solo i nomi che iniziano
# con quella lettera

# %%
# 2. Scrivi una funzione che prende come argomento una frase (stringa)
# e restituisce il numero totale (int) di parole nella frase

# %%
# 3. Scrivi una funzione che prende come argomento una frase (stringa)
# e restituisce il numero totale (int) di parole che iniziano con una vocale

# %%
# 4. Scrivi una funzione che prende come argomento una frase (stringa)
# e restituisce il numero totale (int) di parole che iniziano con una consonante
# SUGGERIMENTO: invece di scrivere una stringa con tutte le consonanti, puoi
# controllare che le lettere NON siano vocali. Le vocali sono molto meno delle consonanti!

# %%
# 5. Scrivi una funzione generate_hashtag() che prende come argomento una frase (stringa)
# e restituisce un hashtag (stringa).
# Esempio: 'do it scared' --> '#DoItScared'

# %%
# 6. Scrivi una funzione che prende come argomenti una lista di numeri interi
# chiamata 'lista_numeri' e un numero singolo (int) chiamato 'soglia'
# e restituisce una lista con solo i numeri maggiori della soglia
# Esempio: lista_numeri=[1, 4, 5, 8, 10], soglia=5 --> [8, 10]

# %%
# 7. Scrivi una funzione filtra_numeri_pari() che prende come argomento
# una lista di numeri interi e restituisce una lista con solo i numeri pari

# %%
# 8. Scrivi una funzione filtra_numeri_dispari() che prende come argomento
# una lista di numeri interi e restituisce una lista con solo i numeri dispari

# %%
# 9. Scrivi una funzione filtra_coordinate() che prende come argomento:
# a. lista_coordinate: una lista di coordinate, rappresentata come una lista di tuple
# --> Esempio: [(42, 12), (43, 13), (45, 12)]
# b. soglia: un numero singolo (int)
# La funzione deve restituire una lista con solo le tuple, il cui PRIMO elemento
# è SUPERIORE alla soglia.
# Esempio: lista_coordinate=[(42, 12), (43, 13), (45, 12)], soglia=42 --> [(43, 13), (45, 12)]

# %%
# 10. Scrivi una funzione filtra_coordinate() che prende come argomento:
# a. lista_coordinate: una lista di coordinate, rappresentata come una lista di tuple
# --> Esempio: [(42, 12), (43, 13), (45, 12)]
# b. soglia: un numero singolo (int)
# La funzione deve restituire una lista con solo le tuple, il cui SECONDO elemento
# è INFERIORE alla soglia.
# Esempio: lista_coordinate=[(42, 12), (43, 13), (45, 12)], soglia=13 --> [(42, 12), (45, 12)]
