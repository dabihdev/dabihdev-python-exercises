# %% [markdown]
# # Esercizi su variabili, print() e tipi di dati

# %%
# Definisci una variabile chiamata 'nome' con il valore "Alice". 
# Stampa il testo "Il nome dell'utente è" seguito dalla variabile 'nome' usando la virgola.

# %%
# Definisci una variabile chiamata 'anni' con il valore intero 25. 
# Stampa il testo "L'età inserita è" seguito dalla variabile 'anni' usando la virgola.

# %%
# Definisci una variabile chiamata 'prezzo' con il valore float 12.50. 
# Stampa il testo "Il costo del prodotto è" seguito dalla variabile 'prezzo' usando la virgola.

# %%
# Definisci una variabile chiamata 'disponibile' con il valore booleano True. 
# Stampa il testo "L'articolo è in magazzino:" seguito dalla variabile 'disponibile' usando la virgola.

# %%
# Definisci una variabile chiamata 'citta' con il valore "Roma". 
# Stampa il testo "La capitale è" seguito dalla variabile 'citta' usando la virgola.

# %%
# Definisci una variabile chiamata 'numero_maglia' con il valore intero 10. 
# Stampa il testo "Il numero del giocatore è" seguito dalla variabile 'numero_maglia' usando la virgola.

# %%
# Definisci una variabile chiamata 'temperatura' con il valore float 36.6. 
# Stampa il testo "La temperatura corporea è" seguito dalla variabile 'temperatura' usando la virgola.

# %%
# Definisci una variabile chiamata 'ha_pagato' con il valore booleano False. 
# Stampa il testo "Stato del pagamento:" seguito dalla variabile 'ha_pagato' usando la virgola.

# %%
# Definisci una variabile chiamata 'colore' con il valore "Blu". 
# Stampa il testo "Il colore preferito è" seguito dalla variabile 'colore' usando la virgola.

# %%
# Definisci una variabile chiamata 'voto' con il valore intero 30. 
# Stampa il testo "Il risultato dell'esame è" seguito dalla variabile 'voto' usando la virgola.
