# %% [markdown]
# # Esercizi su Espressioni Boolean
#
# Pagina web per trovare spunti: https://cs.stanford.edu/people/nick/py/python-boolean.html

# %%
# Crea una variabile 'punti' con valore 85. 
# Stampa il risultato booleano dell'espressione: punti > 100

# %%
# Crea una variabile 'password' con valore "qwerty". 
# Stampa il risultato booleano dell'espressione: password == "12345"

# %%
# Crea una variabile 'altezza' con valore 1.75. 
# Stampa il risultato booleano dell'espressione: altezza >= 1.70

# %%
# Crea una variabile 'nome' con valore "Luca". 
# Stampa il risultato booleano dell'espressione: nome != "Matteo"

# %%
# Crea una variabile 'ore_lavoro' con valore 40. 
# Stampa il risultato booleano dell'espressione: ore_lavoro == 40

# %%
# Crea una variabile 'temperatura' con valore 15.5. 
# Stampa il risultato booleano dell'espressione: temperatura < 0

# %%
# Crea una variabile 'is_admin' con valore True. 
# Stampa il risultato booleano dell'espressione: is_admin == False

# %%
# Crea una variabile 'eta' con valore 16. 
# Stampa il risultato booleano dell'espressione: eta >= 18

# %%
# Crea una variabile 'colore' con valore "rosso". 
# Stampa il risultato booleano dell'espressione: colore == "verde"

# %%
# Crea una variabile 'prezzo' con valore 99.99. 
# Stampa il risultato booleano dell'espressione: prezzo <= 100
