# %% [markdown]
# # Esercizi sulle basi di pandas
# Non serve creare delle funzioni, risolvi gli esercizi con semplici righe di codice.

# %%
import pandas as pd

# --- DATI INIZIALI ---
# Non modificare questa sezione, serve come base per i tuoi esercizi.
data = {
    'Nome': ['Alice', 'Bob', 'Charlie', 'David', 'Elena', 'Federico', 'Giorgia'],
    'Dipartimento': ['HR', 'IT', 'IT', 'Marketing', 'Sales', 'IT', 'Sales'],
    'Stipendio': [31000, 45000, 52000, 38000, 42000, 48000, 33000],
    'Anni_Esperienza': [2, 5, 10, 4, 7, 6, 3]
}

indici_personalizzati = ['ID_001', 'ID_002', 'ID_003', 'ID_004', 'ID_005', 'ID_006', 'ID_007']

# ---------------------------------------------------------
# 1. ESERCIZIO: Crea un DataFrame chiamato 'df' usando il dizionario 'data' 
# e imposta 'indici_personalizzati' come indice delle righe.
# Scrivi qui sotto:


# ---------------------------------------------------------
# 2. ESERCIZIO: Seleziona solo la colonna 'Nome' e salvala in una variabile.
# Scrivi qui sotto:


# ---------------------------------------------------------
# 3. ESERCIZIO: Seleziona le colonne 'Nome' e 'Stipendio' contemporaneamente.
# Scrivi qui sotto:


# ---------------------------------------------------------
# 4. ESERCIZIO: Estrai le prime 3 righe del DataFrame usando il metodo .head().
# Scrivi qui sotto:


# ---------------------------------------------------------
# 5. ESERCIZIO: Estrai le prime 5 righe del DataFrame usando lo slicing ([:n]).
# Scrivi qui sotto:


# ---------------------------------------------------------
# 6. ESERCIZIO: Filtra il DataFrame per mostrare solo chi ha uno 'Stipendio' 
# superiore a 40.000.
# Scrivi qui sotto:


# ---------------------------------------------------------
# 7. ESERCIZIO: Seleziona tutte le righe dove il 'Dipartimento' è uguale a 'IT'.
# Scrivi qui sotto:


# ---------------------------------------------------------
# 8. ESERCIZIO: Filtra i dipendenti che hanno uno 'Stipendio' > 35.000 
# E contemporaneamente più di 5 'Anni_Esperienza'.
# Scrivi qui sotto:


# ---------------------------------------------------------
# 9. ESERCIZIO: Filtra i dipendenti che appartengono al Dipartimento 'HR' 
# OPPURE al Dipartimento 'Marketing'.
# Scrivi qui sotto:


# ---------------------------------------------------------
# 10. ESERCIZIO: Usa .loc per selezionare solo la colonna 'Nome' 
# delle righe in cui 'Anni_Esperienza' è minore di 5.
# Scrivi qui sotto:

# %%
import pandas as pd

# --- DATI INIZIALI ---
# Questa base dati servirà per tutti gli esercizi seguenti.
data = {
    'Nome': ['Alice', 'Bob', 'Charlie', 'David', 'Elena', 'Federico', 'Giorgia', 'Hubert', 'Irene', 'Jacopo'],
    'Dipartimento': ['HR', 'IT', 'IT', 'Marketing', 'Sales', 'IT', 'Sales', 'HR', 'Marketing', 'IT'],
    'Stipendio': [31000, 45000, 52000, 38000, 42000, 48000, 33000, 55000, 29000, 41000],
    'Anni_Esperienza': [2, 5, 10, 4, 7, 6, 3, 12, 1, 8],
    'Progetti_Completati': [5, 12, 25, 8, 15, 20, 10, 30, 2, 18],
    'Ore_Straordinario': [10, 20, 5, 15, 8, 25, 12, 0, 30, 14]
}

df = pd.DataFrame(data)
df.index = ['ID_001', 'ID_002', 'ID_003', 'ID_004', 'ID_005', 'ID_006', 'ID_007', 'ID_008', 'ID_009', 'ID_010']

# ---------------------------------------------------------
# ESEMPIO GUIDA:
# Trova il Nome del dipendente con lo Stipendio più alto.
# id_max = df['Stipendio'].idxmax()
# nome_max = df.loc[id_max, 'Nome']
# ---------------------------------------------------------

# 1. ESERCIZIO: Trova l'indice (ID) della riga con il valore massimo di 'Stipendio'.
# Scrivi qui sotto:


# 2. ESERCIZIO: Usando l'indice trovato nell'esercizio 1, estrai il 'Nome' corrispondente con .loc.
# Scrivi qui sotto:


# 3. ESERCIZIO: Trova il 'Nome' del dipendente con il massimo di 'Anni_Esperienza' in un'unica riga di codice.
# Scrivi qui sotto:


# 4. ESERCIZIO: Individua l'ID (indice) di chi ha completato il maggior numero di 'Progetti_Completati'.
# Scrivi qui sotto:


# 5. ESERCIZIO: Usa .loc e l'indice dell'esercizio precedente per scoprire il 'Dipartimento' di chi ha fatto più progetti.
# Scrivi qui sotto:


# 6. ESERCIZIO: Trova l'indice di chi ha effettuato il maggior numero di 'Ore_Straordinario'.
# Scrivi qui sotto:


# 7. ESERCIZIO: Usando .iloc, estrai il valore della prima colonna (Nome) della prima riga assoluta del DataFrame.
# Scrivi qui sotto:


# 8. ESERCIZIO: Trova il 'Nome' di chi ha il valore massimo in 'Ore_Straordinario' combinando .idxmax() e .loc.
# Scrivi qui sotto:


# 9. ESERCIZIO: Seleziona con .iloc le righe dalla posizione 2 alla 5 (esclusa) e solo la colonna in posizione 0.
# Scrivi qui sotto:


# 10. ESERCIZIO: Trova il 'Dipartimento' del dipendente che ha lo stipendio più alto.
# Scrivi qui sotto:
